# %%
import pandas as pd
import ipaddress
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
import numpy as np
import joblib
from sklearn.ensemble import IsolationForest
pd.set_option('future.no_silent_downcasting', True)
column_names = ['ts', 'uid', 'id.orig_h', 'id.orig_p', 'id.resp_h', 'id.resp_p', 'proto', 'service', 'duration', 'orig_bytes', 'resp_bytes', 'conn_state', 'local_orig', 'local_resp', 'missed_bytes', 'history', 'orig_pkts', 'orig_ip_bytes', 'resp_pkts', 'resp_ip_bytes', 'tunnel_parents', 'ip_proto']
zeek_data = pd.read_csv('/opt/homebrew/opt/zeek/logs/current/conn.log', delimiter='\t', comment='#', names=column_names)
zeek_data
# Out:
#                 ts                 uid  \
# 0     1.741144e+09  C7tWSi3DbIvTBTYwnf
# 1     1.741144e+09   CFPBNz4HGMiwcivw3
# 2     1.741144e+09   C1p0jtaRuZ1qhCyje
# 3     1.741144e+09  Cxjtiz3XudyGzen5K6
# 4     1.741144e+09  CPCXgc3TciTXBc9BHf
# ...            ...                 ...
# 3512  1.741147e+09  CId9EW2ApCeLgrXeT7
# 3513  1.741147e+09   CuYceYU15lxjh5msh
# 3514  1.741147e+09  C6PB6h3c0qapsN7JR7
# 3515  1.741147e+09  CdmUE23yIUKAk1Vwak
# 3516  1.741147e+09  CuuR4b1wyuPBgqXZRc
#
#                                    id.orig_h  id.orig_p  \
# 0     2601:647:cf01:5340:a545:54fc:a1b6:f95f      53947
# 1     2601:647:cf01:5340:a545:54fc:a1b6:f95f      54381
# 2     2601:647:cf01:5340:a545:54fc:a1b6:f95f      64630
# 3     2601:647:cf01:5340:a545:54fc:a1b6:f95f      63987
# 4     2601:647:cf01:5340:a545:54fc:a1b6:f95f      64461
# ...                                      ...        ...
# 3512  2601:647:cf01:5340:a545:54fc:a1b6:f95f      60208
# ...

# %%
zeek_data = zeek_data.dropna(axis=1, how='all')  # Drop columns with all NaN values
zeek_data['ts'] = pd.to_datetime(zeek_data['ts'], unit='s')
zeek_data
# Out:
#                                 ts                 uid  \
# 0    2025-03-05 02:59:51.871107101  C7tWSi3DbIvTBTYwnf
# 1    2025-03-05 02:59:51.871143103   CFPBNz4HGMiwcivw3
# 2    2025-03-05 02:59:51.871171951   C1p0jtaRuZ1qhCyje
# 3    2025-03-05 02:59:51.896135092  Cxjtiz3XudyGzen5K6
# 4    2025-03-05 02:59:51.896281004  CPCXgc3TciTXBc9BHf
# ...                            ...                 ...
# 3512 2025-03-05 03:52:26.827275038  CId9EW2ApCeLgrXeT7
# 3513 2025-03-05 03:52:27.465172052   CuYceYU15lxjh5msh
# 3514 2025-03-05 03:52:27.465215921  C6PB6h3c0qapsN7JR7
# 3515 2025-03-05 03:51:08.654692888  CdmUE23yIUKAk1Vwak
# 3516 2025-03-05 03:51:41.775787115  CuuR4b1wyuPBgqXZRc
#
#                                    id.orig_h  id.orig_p  \
# 0     2601:647:cf01:5340:a545:54fc:a1b6:f95f      53947
# 1     2601:647:cf01:5340:a545:54fc:a1b6:f95f      54381
# 2     2601:647:cf01:5340:a545:54fc:a1b6:f95f      64630
# 3     2601:647:cf01:5340:a545:54fc:a1b6:f95f      63987
# ...

# %%
# Drop rows with missing values
zeek_data = zeek_data.dropna()

# Or fill missing values with a placeholder, for example, 0
zeek_data = zeek_data.fillna(0)

# %%
zeek_data.columns = zeek_data.columns.str.strip()  # Remove any leading/trailing spaces
zeek_data.columns = zeek_data.columns.str.lower()  # Convert all column names to lowercase
zeek_data
# Out:
#                                 ts                 uid  \
# 0    2025-03-05 02:59:51.871107101  C7tWSi3DbIvTBTYwnf
# 1    2025-03-05 02:59:51.871143103   CFPBNz4HGMiwcivw3
# 2    2025-03-05 02:59:51.871171951   C1p0jtaRuZ1qhCyje
# 3    2025-03-05 02:59:51.896135092  Cxjtiz3XudyGzen5K6
# 4    2025-03-05 02:59:51.896281004  CPCXgc3TciTXBc9BHf
# ...                            ...                 ...
# 3512 2025-03-05 03:52:26.827275038  CId9EW2ApCeLgrXeT7
# 3513 2025-03-05 03:52:27.465172052   CuYceYU15lxjh5msh
# 3514 2025-03-05 03:52:27.465215921  C6PB6h3c0qapsN7JR7
# 3515 2025-03-05 03:51:08.654692888  CdmUE23yIUKAk1Vwak
# 3516 2025-03-05 03:51:41.775787115  CuuR4b1wyuPBgqXZRc
#
#                                    id.orig_h  id.orig_p  \
# 0     2601:647:cf01:5340:a545:54fc:a1b6:f95f      53947
# 1     2601:647:cf01:5340:a545:54fc:a1b6:f95f      54381
# 2     2601:647:cf01:5340:a545:54fc:a1b6:f95f      64630
# 3     2601:647:cf01:5340:a545:54fc:a1b6:f95f      63987
# ...

# %%
zeek_data.replace(['...', '-'], pd.NA, inplace=True)
zeek_data.fillna(0, inplace=True)
zeek_data
# Out:
#                                 ts                 uid  \
# 0    2025-03-05 02:59:51.871107101  C7tWSi3DbIvTBTYwnf
# 1    2025-03-05 02:59:51.871143103   CFPBNz4HGMiwcivw3
# 2    2025-03-05 02:59:51.871171951   C1p0jtaRuZ1qhCyje
# 3    2025-03-05 02:59:51.896135092  Cxjtiz3XudyGzen5K6
# 4    2025-03-05 02:59:51.896281004  CPCXgc3TciTXBc9BHf
# ...                            ...                 ...
# 3512 2025-03-05 03:52:26.827275038  CId9EW2ApCeLgrXeT7
# 3513 2025-03-05 03:52:27.465172052   CuYceYU15lxjh5msh
# 3514 2025-03-05 03:52:27.465215921  C6PB6h3c0qapsN7JR7
# 3515 2025-03-05 03:51:08.654692888  CdmUE23yIUKAk1Vwak
# 3516 2025-03-05 03:51:41.775787115  CuuR4b1wyuPBgqXZRc
#
#                                    id.orig_h  id.orig_p  \
# 0     2601:647:cf01:5340:a545:54fc:a1b6:f95f      53947
# 1     2601:647:cf01:5340:a545:54fc:a1b6:f95f      54381
# 2     2601:647:cf01:5340:a545:54fc:a1b6:f95f      64630
# 3     2601:647:cf01:5340:a545:54fc:a1b6:f95f      63987
# ...

# %%
zeek_data.isnull().sum()
# Out:
# ts                0
# uid               0
# id.orig_h         0
# id.orig_p         0
# id.resp_h         0
# id.resp_p         0
# proto             0
# service           0
# duration          0
# orig_bytes        0
# resp_bytes        0
# conn_state        0
# local_orig        0
# local_resp        0
# missed_bytes      0
# history           0
# orig_pkts         0
# orig_ip_bytes     0
# resp_pkts         0
# resp_ip_bytes     0
# tunnel_parents    0
# ip_proto          0
# dtype: int64

# %%
zeek_data.columns
# Out:
# Index(['ts', 'uid', 'id.orig_h', 'id.orig_p', 'id.resp_h', 'id.resp_p',
#        'proto', 'service', 'duration', 'orig_bytes', 'resp_bytes',
#        'conn_state', 'local_orig', 'local_resp', 'missed_bytes', 'history',
#        'orig_pkts', 'orig_ip_bytes', 'resp_pkts', 'resp_ip_bytes',
#        'tunnel_parents', 'ip_proto'],
#       dtype='object')

# %%
zeek_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3517 entries, 0 to 3516
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ts              3517 non-null   datetime64[ns]
#  1   uid             3517 non-null   object
#  2   id.orig_h       3517 non-null   object
#  3   id.orig_p       3517 non-null   int64
#  4   id.resp_h       3517 non-null   object
#  5   id.resp_p       3517 non-null   int64
#  6   proto           3517 non-null   object
#  7   service         3517 non-null   object
#  8   duration        3517 non-null   object
#  9   orig_bytes      3517 non-null   object
#  10  resp_bytes      3517 non-null   object
#  11  conn_state      3517 non-null   object
#  12  local_orig      3517 non-null   object
#  13  local_resp      3517 non-null   object
#  14  missed_bytes    3517 non-null   int64
#  15  history         3517 non-null   object
#  16  orig_pkts       3517 non-null   int64
# ...

# %%
zeek_data['duration'] = pd.to_numeric(zeek_data['duration'], errors='coerce')  # Convert duration to numeric (coerce invalid values to NaN)
zeek_data['orig_bytes'] = pd.to_numeric(zeek_data['orig_bytes'], errors='coerce')  # Convert orig_bytes to numeric
zeek_data['resp_bytes'] = pd.to_numeric(zeek_data['resp_bytes'], errors='coerce')  # Convert resp_bytes to numeric

# %%
def standardize_ip(ip):
    try:
        return str(ipaddress.ip_address(ip))
    except ValueError:
        return ip

zeek_data['id.orig_h'] = zeek_data['id.orig_h'].apply(standardize_ip)
zeek_data['id.resp_h'] = zeek_data['id.resp_h'].apply(standardize_ip)

zeek_data
# Out:
#                                 ts                 uid  \
# 0    2025-03-05 02:59:51.871107101  C7tWSi3DbIvTBTYwnf
# 1    2025-03-05 02:59:51.871143103   CFPBNz4HGMiwcivw3
# 2    2025-03-05 02:59:51.871171951   C1p0jtaRuZ1qhCyje
# 3    2025-03-05 02:59:51.896135092  Cxjtiz3XudyGzen5K6
# 4    2025-03-05 02:59:51.896281004  CPCXgc3TciTXBc9BHf
# ...                            ...                 ...
# 3512 2025-03-05 03:52:26.827275038  CId9EW2ApCeLgrXeT7
# 3513 2025-03-05 03:52:27.465172052   CuYceYU15lxjh5msh
# 3514 2025-03-05 03:52:27.465215921  C6PB6h3c0qapsN7JR7
# 3515 2025-03-05 03:51:08.654692888  CdmUE23yIUKAk1Vwak
# 3516 2025-03-05 03:51:41.775787115  CuuR4b1wyuPBgqXZRc
#
#                                    id.orig_h  id.orig_p  \
# 0     2601:647:cf01:5340:a545:54fc:a1b6:f95f      53947
# 1     2601:647:cf01:5340:a545:54fc:a1b6:f95f      54381
# 2     2601:647:cf01:5340:a545:54fc:a1b6:f95f      64630
# 3     2601:647:cf01:5340:a545:54fc:a1b6:f95f      63987
# ...

# %%
zeek_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3517 entries, 0 to 3516
# Data columns (total 22 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ts              3517 non-null   datetime64[ns]
#  1   uid             3517 non-null   object
#  2   id.orig_h       3517 non-null   object
#  3   id.orig_p       3517 non-null   int64
#  4   id.resp_h       3517 non-null   object
#  5   id.resp_p       3517 non-null   int64
#  6   proto           3517 non-null   object
#  7   service         3517 non-null   object
#  8   duration        3517 non-null   float64
#  9   orig_bytes      3517 non-null   int64
#  10  resp_bytes      3517 non-null   int64
#  11  conn_state      3517 non-null   object
#  12  local_orig      3517 non-null   object
#  13  local_resp      3517 non-null   object
#  14  missed_bytes    3517 non-null   int64
#  15  history         3517 non-null   object
#  16  orig_pkts       3517 non-null   int64
# ...

# %%
zeek_data_encoded = pd.get_dummies(zeek_data, columns=['proto', 'service', 'conn_state', 'local_orig', 'local_resp', 'history', 'tunnel_parents','id.orig_h', 'id.resp_h' ], drop_first=True)

zeek_data_encoded.info()
zeek_data_encoded
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3517 entries, 0 to 3516
# Columns: 477 entries, ts to id.resp_h_ff02::fb
# dtypes: bool(464), datetime64[ns](1), float64(1), int64(10), object(1)
# memory usage: 1.9+ MB
#                                 ts                 uid  id.orig_p  id.resp_p  \
# 0    2025-03-05 02:59:51.871107101  C7tWSi3DbIvTBTYwnf      53947         53
# 1    2025-03-05 02:59:51.871143103   CFPBNz4HGMiwcivw3      54381         53
# 2    2025-03-05 02:59:51.871171951   C1p0jtaRuZ1qhCyje      64630         53
# 3    2025-03-05 02:59:51.896135092  Cxjtiz3XudyGzen5K6      63987         53
# 4    2025-03-05 02:59:51.896281004  CPCXgc3TciTXBc9BHf      64461         53
# ...                            ...                 ...        ...        ...
# 3512 2025-03-05 03:52:26.827275038  CId9EW2ApCeLgrXeT7      60208         53
# 3513 2025-03-05 03:52:27.465172052   CuYceYU15lxjh5msh      50514         53
# ...

# %%
zeek_data_encoded
# Out:
#                                 ts                 uid  id.orig_p  id.resp_p  \
# 0    2025-03-05 02:59:51.871107101  C7tWSi3DbIvTBTYwnf      53947         53
# 1    2025-03-05 02:59:51.871143103   CFPBNz4HGMiwcivw3      54381         53
# 2    2025-03-05 02:59:51.871171951   C1p0jtaRuZ1qhCyje      64630         53
# 3    2025-03-05 02:59:51.896135092  Cxjtiz3XudyGzen5K6      63987         53
# 4    2025-03-05 02:59:51.896281004  CPCXgc3TciTXBc9BHf      64461         53
# ...                            ...                 ...        ...        ...
# 3512 2025-03-05 03:52:26.827275038  CId9EW2ApCeLgrXeT7      60208         53
# 3513 2025-03-05 03:52:27.465172052   CuYceYU15lxjh5msh      50514         53
# 3514 2025-03-05 03:52:27.465215921  C6PB6h3c0qapsN7JR7      50320         53
# 3515 2025-03-05 03:51:08.654692888  CdmUE23yIUKAk1Vwak          0          0
# 3516 2025-03-05 03:51:41.775787115  CuuR4b1wyuPBgqXZRc        135        136
#
# ...

# %%
features = zeek_data_encoded.drop(columns=['uid', 'ts'])

# Scale the features
scaler = StandardScaler()
features_scaled = scaler.fit_transform(features)


X_train, X_test = train_test_split(features_scaled, test_size=0.2, random_state=42)

# Build the Sequential Autoencoder Model
learning_rate = 0.01
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)

model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(input_shape=(X_train.shape[1],)),  # Input layer size is the number of features
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(X_train.shape[1], activation='sigmoid')  # Output layer should match input size
])
model.compile(optimizer=optimizer, loss='mean_squared_error')

model.fit(X_train, X_train, epochs=50, batch_size=32, validation_data=(X_test, X_test))

reconstructions = model.predict(X_test)
mse = np.mean(np.power(X_test - reconstructions, 2), axis=1)

threshold = np.percentile(mse, 98)

anomalies = mse > threshold
print(f"Anomalies detected: {np.sum(anomalies)}")

anomalous_indices = np.where(anomalies)[0]
anomalous_traffic = zeek_data_encoded.iloc[anomalous_indices]

print(anomalous_traffic)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 1.0683 - val_loss: 0.7852
# Epoch 2/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9887 - val_loss: 0.7852
# Epoch 3/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1328 - val_loss: 0.7852
# Epoch 4/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0088 - val_loss: 0.7852
# Epoch 5/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0746 - val_loss: 0.7852
# Epoch 6/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0544 - val_loss: 0.7852
# Epoch 7/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0318 - val_loss: 0.7852
# Epoch 8/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9753 - val_loss: 0.7852
# Epoch 9/50
# 88/88 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1115 - val_loss: 0.7852
# Epoch 10/50
# ...

# %%
# Extract columns where the value is True for each row
anomalous_traffic_values = anomalous_traffic.loc[:, anomalous_traffic.any(axis=0)]

# Iterate over each row and extract only the values that are True in the corresponding columns
for idx, row in anomalous_traffic_values.iterrows():
    print(f"Anomalous row {idx} (Values that are True):")
    anomalous_values = row[row == True].index.tolist()  # Get column names where the value is True
    print(anomalous_values)  # This will print the column names where anomalies were detected
    print("Values:", row[anomalous_values].tolist())  # This will print the corresponding values
    print("\n")
# Out:
# Anomalous row 45 (Values that are True):
# ['orig_pkts', 'resp_pkts', 'proto_udp', 'service_dns', 'conn_state_SF', 'history_Dd', 'id.orig_h_2601:647:cf01:5340:a545:54fc:a1b6:f95f', 'id.resp_h_2001:558:feed::1']
# Values: [1, 1, True, True, True, True, True, True]
#
#
# Anomalous row 54 (Values that are True):
# ['proto_tcp', 'service_ssl', 'conn_state_SF', 'history_ShADadFf', 'id.orig_h_2601:647:cf01:5340:a545:54fc:a1b6:f95f', 'id.resp_h_2001:558:feed:443::148']
# Values: [True, True, True, True, True, True]
#
#
# Anomalous row 59 (Values that are True):
# ['local_orig_T', 'local_resp_T', 'id.orig_h_fe80::833:d877:dbce:6f45', 'id.resp_h_fe80::1cfa:9bf0:c264:c9d2']
# Values: [True, True, True, True]
#
#
# Anomalous row 97 (Values that are True):
# ['orig_pkts', 'resp_pkts', 'proto_udp', 'service_dns', 'conn_state_SF', 'history_Dd', 'id.orig_h_2601:647:cf01:5340:a545:54fc:a1b6:f95f', 'id.resp_h_2001:558:feed::1']
# Values: [1, 1, True, True, True, True, True, True]
#
#
# ...

# %%
reconstructions = model.predict(features_scaled)
mse = np.mean(np.power(features_scaled - reconstructions, 2), axis=1)

threshold = np.percentile(mse, 99)

anomalies = mse > threshold  # Ensure this 'anomalies' array is calculated from the same dataset as features_scaled

pca = PCA(n_components=2)
reduced_data = pca.fit_transform(features_scaled)

plt.figure(figsize=(10, 6))
plt.scatter(reduced_data[~anomalies, 0], reduced_data[~anomalies, 1], c='blue', label='Normal')
plt.scatter(reduced_data[anomalies, 0], reduced_data[anomalies, 1], c='red', label='Anomalies')

plt.title('Anomalous Traffic Visualization (PCA)')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend()
plt.show()
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 697us/step

# %%
model = IsolationForest()
model.fit(reduced_data)

joblib.dump(model, 'anomaly_detection_model.pkl')

loaded_model = joblib.load('anomaly_detection_model.pkl')


predictions = loaded_model.predict(reduced_data)

anomalies = predictions == -1

print(anomalies)

new_reduced_data = pca.transform(new_data)  

new_predictions = loaded_model.predict(new_reduced_data)

new_anomalies = new_predictions == -1
print(new_anomalies)
# Out:
# [False False False ... False  True  True]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[349], line 15
#      11 anomalies = predictions == -1
#      13 print(anomalies)
# ---> 15 new_reduced_data = pca.transform(new_data)
#      17 new_predictions = loaded_model.predict(new_reduced_data)
#      19 new_anomalies = new_predictions == -1
#
# NameError: name 'new_data' is not defined
